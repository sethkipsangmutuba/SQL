# %% [markdown]
# <a href="https://colab.research.google.com/github/sethkipsangmutuba/SQL/blob/main/1b.Using_logical_and_comparison_operators_%5BNotebook%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Titanic Dataset – SQL with Logic & Comparison Operators (SQLite + Colab)

# %% [markdown]
# ##Comparison Operators in SQL
#
# Use comparison operators in the `WHERE` clause to filter rows based on specific conditions.
#
# | Operator           | Description              | Example                          |
# |--------------------|---------------------------|-----------------------------------|
# | `=`                | Equal to                  | `WHERE sex = 'female'`           |
# | `!=` or `<>`       | Not equal to              | `WHERE class != 'First'`         |
# | `>`                | Greater than              | `WHERE fare > 50`                |
# | `<`                | Less than                 | `WHERE age < 18`                 |
# | `>=`               | Greater than or equal to  | `WHERE age >= 60`                |
# | `<=`               | Less than or equal to     | `WHERE fare <= 15`               |
# | `BETWEEN ... AND`  | Range (inclusive)         | `WHERE age BETWEEN 20 AND 30`    |

# %%
import seaborn as sns
import sqlite3
import pandas as pd

df = sns.load_dataset("titanic")
conn = sqlite3.connect("titanic.db")
df.to_sql("titanic", conn, if_exists="replace", index=False)
# Out:
# 891

# %% [markdown]
# #### Basic Filtering with `OR` and Comparison Operators
#
# **Objective:**
# Select passengers who are either **male** or **female** (explicit `OR` usage),
# **and** whose age is **between 20 and 30**.
#
# > Add blockquote

# %%
pd.read_sql("""
SELECT sex, age, class, fare
FROM titanic
WHERE (sex = 'male' OR sex = 'female')
AND age BETWEEN 20 AND 30
""", conn)
# Out:
#         sex   age   class     fare
# 0      male  22.0   Third   7.2500
# 1    female  26.0   Third   7.9250
# 2    female  27.0   Third  11.1333
# 3      male  20.0   Third   8.0500
# 4      male  28.0   First  35.5000
# ..      ...   ...     ...      ...
# 240  female  22.0   Third  10.5167
# 241    male  28.0  Second  10.5000
# 242    male  25.0   Third   7.0500
# 243    male  27.0  Second  13.0000
# 244    male  26.0   First  30.0000
#
# [245 rows x 4 columns]

# %% [markdown]
# #Using IN instead of OR
# Same logic, simplified with IN operator

# %%
pd.read_sql("""
SELECT sex, age, class, fare
FROM titanic
WHERE sex IN ('male', 'female')
AND age BETWEEN 20 AND 30
""", conn)
# Out:
#         sex   age   class     fare
# 0      male  22.0   Third   7.2500
# 1    female  26.0   Third   7.9250
# 2    female  27.0   Third  11.1333
# 3      male  20.0   Third   8.0500
# 4      male  28.0   First  35.5000
# ..      ...   ...     ...      ...
# 240  female  22.0   Third  10.5167
# 241    male  28.0  Second  10.5000
# 242    male  25.0   Third   7.0500
# 243    male  27.0  Second  13.0000
# 244    male  26.0   First  30.0000
#
# [245 rows x 4 columns]

# %% [markdown]
# ##Combining Multiple Conditions with `<=` and `AND`
#
# **Objective:**
# Find passengers who:
# - Were in **3rd class**
# - **Survived** (i.e., `survived = 1`)
# - Paid **fare less than or equal to 10**

# %%
pd.read_sql("""
SELECT sex, age, class, fare, survived
FROM titanic
WHERE class = 'Third'
AND survived = 1
AND fare <= 10
""", conn)
# Out:
#        sex   age  class    fare  survived
# 0   female  26.0  Third  7.9250         1
# 1   female   NaN  Third  7.2250         1
# 2   female  15.0  Third  8.0292         1
# 3   female   NaN  Third  7.8792         1
# 4   female   NaN  Third  7.7500         1
# ..     ...   ...    ...     ...       ...
# 62    male  27.0  Third  6.9750         1
# 63    male  27.0  Third  8.6625         1
# 64    male   NaN  Third  7.7500         1
# 65  female  18.0  Third  9.3500         1
# 66  female  15.0  Third  7.2250         1
#
# [67 rows x 5 columns]

# %% [markdown]
# Passengers aged ≥ 60

# %%
pd.read_sql("""
SELECT age, sex, class FROM titanic
WHERE age >= 60
""", conn)
# Out:
#      age     sex   class
# 0   66.0    male  Second
# 1   65.0    male   First
# 2   71.0    male   First
# 3   70.5    male   Third
# 4   61.0    male   First
# 5   62.0    male   First
# 6   63.0  female   First
# 7   65.0    male   Third
# 8   61.0    male   Third
# 9   60.0  female   First
# 10  64.0    male   First
# 11  65.0    male   First
# 12  63.0  female   Third
# 13  71.0    male   First
# 14  64.0    male   First
# 15  62.0    male   First
# 16  62.0    male  Second
# 17  60.0    male   First
# 18  61.0    male   First
# 19  80.0    male   First
# 20  70.0    male  Second
# 21  60.0    male  Second
# 22  60.0    male   First
# 23  70.0    male   First
# 24  62.0  female   First
# 25  74.0    male   Third

# %% [markdown]
# Passengers with fare between 10 and 50

# %%
pd.read_sql("""
SELECT age, fare, class FROM titanic
WHERE fare BETWEEN 10 AND 50
""", conn)
# Out:
#       age     fare   class
# 0     2.0  21.0750   Third
# 1    27.0  11.1333   Third
# 2    14.0  30.0708  Second
# 3     4.0  16.7000   Third
# 4    58.0  26.5500   First
# ..    ...      ...     ...
# 390  39.0  29.1250   Third
# 391  27.0  13.0000  Second
# 392  19.0  30.0000   First
# 393   NaN  23.4500   Third
# 394  26.0  30.0000   First
#
# [395 rows x 3 columns]

# %% [markdown]
# Passengers not in 1st class

# %%
pd.read_sql("""
SELECT age, class, fare FROM titanic
WHERE class != 'First'
""", conn)
# Out:
#       age   class     fare
# 0    22.0   Third   7.2500
# 1    26.0   Third   7.9250
# 2    35.0   Third   8.0500
# 3     NaN   Third   8.4583
# 4     2.0   Third  21.0750
# ..    ...     ...      ...
# 670  25.0   Third   7.0500
# 671  39.0   Third  29.1250
# 672  27.0  Second  13.0000
# 673   NaN   Third  23.4500
# 674  32.0   Third   7.7500
#
# [675 rows x 3 columns]

# %% [markdown]
# Female survivors under age 30

# %%
pd.read_sql("""
SELECT sex, age, survived FROM titanic
WHERE sex = 'female' AND age < 30 AND survived = 1
""", conn)
# Out:
#         sex   age  survived
# 0    female  26.0         1
# 1    female  27.0         1
# 2    female  14.0         1
# 3    female   4.0         1
# 4    female  15.0         1
# ..      ...   ...       ...
# 100  female  27.0         1
# 101  female  28.0         1
# 102  female  15.0         1
# 103  female  25.0         1
# 104  female  19.0         1
#
# [105 rows x 3 columns]

# %% [markdown]
# Male OR 1st class passengers

# %%
pd.read_sql("""
SELECT sex, age, class FROM titanic
WHERE sex = 'male' OR class = 'First'
""", conn)
# Out:
#         sex   age   class
# 0      male  22.0   Third
# 1    female  38.0   First
# 2    female  35.0   First
# 3      male  35.0   Third
# 4      male   NaN   Third
# ..      ...   ...     ...
# 666    male  25.0   Third
# 667    male  27.0  Second
# 668  female  19.0   First
# 669    male  26.0   First
# 670    male  32.0   Third
#
# [671 rows x 3 columns]

# %% [markdown]
# Passengers whose class is in a specific list

# %%
pd.read_sql("""
SELECT age, class FROM titanic
WHERE class IN ('Second', 'Third')
""", conn)
# Out:
#       age   class
# 0    22.0   Third
# 1    26.0   Third
# 2    35.0   Third
# 3     NaN   Third
# 4     2.0   Third
# ..    ...     ...
# 670  25.0   Third
# 671  39.0   Third
# 672  27.0  Second
# 673   NaN   Third
# 674  32.0   Third
#
# [675 rows x 2 columns]

# %% [markdown]
# Passengers whose deck is not in a specific list

# %%
pd.read_sql("""
SELECT deck, age FROM titanic
WHERE deck NOT IN ('A', 'B', 'C')
""", conn)
# Out:
#    deck   age
# 0     E  54.0
# 1     G   4.0
# 2     D  34.0
# 3     D  49.0
# 4     F  29.0
# ..  ...   ...
# 77    E  39.0
# 78    D  16.0
# 79    E  51.0
# 80    D  48.0
# 81    D  47.0
#
# [82 rows x 2 columns]

# %% [markdown]
# Passengers with missing (NULL) age

# %%
pd.read_sql("""
SELECT age, class FROM titanic
WHERE age IS NULL
""", conn)
# Out:
#       age   class
# 0    None   Third
# 1    None  Second
# 2    None   Third
# 3    None   Third
# 4    None   Third
# ..    ...     ...
# 172  None   Third
# 173  None   Third
# 174  None   Third
# 175  None   Third
# 176  None   Third
#
# [177 rows x 2 columns]

# %% [markdown]
# Passengers with a known (NOT NULL) age

# %%
pd.read_sql("""
SELECT age, class FROM titanic
WHERE age IS NOT NULL
""", conn)
# Out:
#       age   class
# 0    22.0   Third
# 1    38.0   First
# 2    26.0   Third
# 3    35.0   First
# 4    35.0   Third
# ..    ...     ...
# 709  39.0   Third
# 710  27.0  Second
# 711  19.0   First
# 712  26.0   First
# 713  32.0   Third
#
# [714 rows x 2 columns]

# %% [markdown]
# Names containing "Mrs" using LIKE

# %%
pd.read_sql("""
SELECT who, sex, class FROM titanic
WHERE who LIKE '%woman%'
""", conn)
# Out:
#        who     sex   class
# 0    woman  female   First
# 1    woman  female   Third
# 2    woman  female   First
# 3    woman  female   Third
# 4    woman  female   First
# ..     ...     ...     ...
# 266  woman  female  Second
# 267  woman  female   Third
# 268  woman  female   Third
# 269  woman  female   First
# 270  woman  female   Third
#
# [271 rows x 3 columns]

# %% [markdown]
# Survivors in 2nd class, female, age under 40

# %%
pd.read_sql("""
SELECT sex, age, class, survived FROM titanic
WHERE survived = 1 AND class = 'Second' AND sex = 'female' AND age < 40
""", conn)
# Out:
#        sex   age   class  survived
# 0   female  14.0  Second         1
# 1   female   3.0  Second         1
# 2   female  29.0  Second         1
# 3   female  21.0  Second         1
# 4   female   5.0  Second         1
# 5   female  29.0  Second         1
# 6   female  17.0  Second         1
# 7   female  34.0  Second         1
# 8   female  32.5  Second         1
# 9   female  29.0  Second         1
# 10  female  32.0  Second         1
# 11  female  35.0  Second         1
# 12  female   8.0  Second         1
# 13  female  24.0  Second         1
# 14  female  24.0  Second         1
# 15  female  30.0  Second         1
# 16  female  22.0  Second         1
# 17  female  36.0  Second         1
# 18  female  24.0  Second         1
# 19  female  36.0  Second         1
# 20  female  17.0  Second         1
# 21  female  28.0  Second         1
# 22  female  34.0  Second         1
# 23  female  18.0  Second         1
# 24  female  28.0  Second         1
# 25  female  19.0  Second         1
# 26  female  24.0  Second         1
# 27  female  28.0  Second         1
# 28  female  13.0  Second         1
# 29  female  33.0  Second         1
# 30  female  23.0  Second         1
# 31  female  33.0  Second         1
# 32  female  34.0  Second         1
# 33  female  36.0  Second         1
# 34  female   2.0  Second         1
# 35  female   7.0  Second         1
# 36  female  19.0  Second         1
# 37  female  34.0  Second         1
# 38  female  25.0  Second         1
# 39  female  24.0  Second         1
# 40  female  22.0  Second         1
# 41  female  24.0  Second         1
# 42  female   4.0  Second         1
# 43  female  28.0  Second         1
# 44  female  18.0  Second         1
# 45  female  27.0  Second         1
# 46  female   6.0  Second         1
# 47  female  30.0  Second         1
# 48  female  30.0  Second         1
# 49  female   4.0  Second         1
# 50  female  31.0  Second         1
# 51  female  27.0  Second         1
# 52  female  28.0  Second         1
# 53  female  25.0  Second         1

# %% [markdown]
# Survivors in 3rd class under age 10 OR over age 60

# %%
pd.read_sql("""
SELECT age, class, survived FROM titanic
WHERE class = 'Third' AND survived = 1 AND (age < 10 OR age > 60)
""", conn)
# Out:
#       age  class  survived
# 0    4.00  Third         1
# 1    9.00  Third         1
# 2    1.00  Third         1
# 3    4.00  Third         1
# 4    5.00  Third         1
# 5    3.00  Third         1
# 6    3.00  Third         1
# 7    1.00  Third         1
# 8    5.00  Third         1
# 9    0.75  Third         1
# 10   2.00  Third         1
# 11  63.00  Third         1
# 12   9.00  Third         1
# 13   0.75  Third         1
# 14   4.00  Third         1
# 15   6.00  Third         1
# 16   5.00  Third         1
# 17   1.00  Third         1
# 18   0.42  Third         1
# 19   4.00  Third         1
