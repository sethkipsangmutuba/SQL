# %% [markdown]
# <a href="https://colab.research.google.com/github/sethkipsangmutuba/SQL/blob/main/1a.%20Querying_in_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SELECT and SELECT WHERE in Colab using Titanic Dataset
#
# ##Setup: Load Titanic into SQLite

# %%
import seaborn as sns
import sqlite3
import pandas as pd

# Load dataset and create SQLite database
df = sns.load_dataset("titanic")
conn = sqlite3.connect("titanic.db")
df.to_sql("titanic", conn, if_exists="replace", index=False)
# Out:
# 891

# %% [markdown]
# ##**Exploring the table: SELECT ***
# View all columns (limited to 10 rows)

# %%
pd.read_sql("SELECT * FROM titanic LIMIT 10", conn)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man           1  None  Southampton    no      0
# 1  woman           0     C    Cherbourg   yes      0
# 2  woman           0  None  Southampton   yes      1
# 3  woman           0     C  Southampton   yes      0
# 4    man           1  None  Southampton    no      1
# 5    man           1  None   Queenstown    no      1
# 6    man           1     E  Southampton    no      1
# 7  child           0  None  Southampton    no      0
# 8  woman           0  None  Southampton   yes      0
# 9  child           0  None    Cherbourg   yes      0

# %% [markdown]
# ## Unique values using `SELECT DISTINCT`
#
# Use the `SELECT DISTINCT` statement to retrieve unique values from a column.

# %%
pd.read_sql("SELECT DISTINCT embark_town FROM titanic", conn)
# Out:
#    embark_town
# 0  Southampton
# 1    Cherbourg
# 2   Queenstown
# 3         None

# %% [markdown]
# #Save into a new table Embark_Towns

# %%
conn.execute("CREATE TABLE IF NOT EXISTS Embark_Towns AS SELECT DISTINCT embark_town FROM titanic")
pd.read_sql("SELECT * FROM Embark_Towns", conn)
# Out:
#    embark_town
# 0  Southampton
# 1    Cherbourg
# 2   Queenstown
# 3         None

# %% [markdown]
# ##Selecting specific fields
#
# Use the `SELECT` statement to retrieve specific columns from a table.

# %%
pd.read_sql("""
SELECT sex, age, survived
FROM titanic
WHERE sex = 'female' AND survived = 0
ORDER BY age
LIMIT 5
""", conn)
# Out:
#       sex   age  survived
# 0  female  None         0
# 1  female  None         0
# 2  female  None         0
# 3  female  None         0
# 4  female  None         0

# %% [markdown]
# #SELECT WHERE IN – Match multiple values
# Get passengers who embarked from either 'Cherbourg' or 'Southampton':

# %%
pd.read_sql("""
SELECT * FROM titanic
WHERE embark_town IN ('Cherbourg', 'Southampton')
LIMIT 10
""", conn)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       1    male  54.0      0      0  51.8625        S   First
# 6         0       3    male   2.0      3      1  21.0750        S   Third
# 7         1       3  female  27.0      0      2  11.1333        S   Third
# 8         1       2  female  14.0      1      0  30.0708        C  Second
# 9         1       3  female   4.0      1      1  16.7000        S   Third
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man           1  None  Southampton    no      0
# 1  woman           0     C    Cherbourg   yes      0
# 2  woman           0  None  Southampton   yes      1
# 3  woman           0     C  Southampton   yes      0
# 4    man           1  None  Southampton    no      1
# 5    man           1     E  Southampton    no      1
# 6  child           0  None  Southampton    no      0
# 7  woman           0  None  Southampton   yes      0
# 8  child           0  None    Cherbourg   yes      0
# 9  child           0     G  Southampton   yes      0

# %% [markdown]
# #SELECT WHERE IS NULL / IS NOT NULL – Handle missing data
# Find passengers with missing age values:

# %%
pd.read_sql("""
SELECT * FROM titanic
WHERE age IS NULL
""", conn)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  None      0      0   8.4583        Q   Third
# 1           1       2    male  None      0      0  13.0000        S  Second
# 2           1       3  female  None      0      0   7.2250        C   Third
# 3           0       3    male  None      0      0   7.2250        C   Third
# 4           1       3  female  None      0      0   7.8792        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 172         0       3    male  None      0      0   7.2292        C   Third
# 173         0       3  female  None      8      2  69.5500        S   Third
# 174         0       3    male  None      0      0   9.5000        S   Third
# 175         0       3    male  None      0      0   7.8958        S   Third
# 176         0       3  female  None      1      2  23.4500        S   Third
#
#        who  adult_male  deck  embark_town alive  alone
# 0      man           1  None   Queenstown    no      1
# 1      man           1  None  Southampton   yes      1
# 2    woman           0  None    Cherbourg   yes      1
# 3      man           1  None    Cherbourg    no      1
# 4    woman           0  None   Queenstown   yes      1
# ..     ...         ...   ...          ...   ...    ...
# 172    man           1  None    Cherbourg    no      1
# 173  woman           0  None  Southampton    no      0
# 174    man           1  None  Southampton    no      1
# 175    man           1  None  Southampton    no      1
# 176  woman           0  None  Southampton    no      0
#
# [177 rows x 15 columns]

# %% [markdown]
# Find passengers with non-null age:

# %%
pd.read_sql("""
SELECT * FROM titanic
WHERE age IS NOT NULL
LIMIT 10
""", conn)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       1    male  54.0      0      0  51.8625        S   First
# 6         0       3    male   2.0      3      1  21.0750        S   Third
# 7         1       3  female  27.0      0      2  11.1333        S   Third
# 8         1       2  female  14.0      1      0  30.0708        C  Second
# 9         1       3  female   4.0      1      1  16.7000        S   Third
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man           1  None  Southampton    no      0
# 1  woman           0     C    Cherbourg   yes      0
# 2  woman           0  None  Southampton   yes      1
# 3  woman           0     C  Southampton   yes      0
# 4    man           1  None  Southampton    no      1
# 5    man           1     E  Southampton    no      1
# 6  child           0  None  Southampton    no      0
# 7  woman           0  None  Southampton   yes      0
# 8  child           0  None    Cherbourg   yes      0
# 9  child           0     G  Southampton   yes      0

# %% [markdown]
# #SELECT WHERE LIKE – Pattern matching
# Find passengers whose names contain the substring "Mrs":

# %% [markdown]
# #SELECT WHERE BETWEEN – Filter within a range
# Get passengers whose age is between 20 and 30:

# %%
pd.read_sql("""
SELECT sex, age, class
FROM titanic
WHERE age BETWEEN 20 AND 30
LIMIT 10
""", conn)
# Out:
#       sex   age   class
# 0    male  22.0   Third
# 1  female  26.0   Third
# 2  female  27.0   Third
# 3    male  20.0   Third
# 4    male  28.0   First
# 5    male  28.0   First
# 6    male  21.0   Third
# 7  female  27.0  Second
# 8    male  21.0   Third
# 9  female  29.0  Second

# %% [markdown]
# #SELECT WHERE AND / OR – Combine conditions
# Find male passengers older than 60:

# %%
pd.read_sql("""
SELECT age, sex, class, fare
FROM titanic
WHERE sex = 'male' AND age > 60
""", conn)
# Out:
#      age   sex   class      fare
# 0   66.0  male  Second   10.5000
# 1   65.0  male   First   61.9792
# 2   71.0  male   First   34.6542
# 3   70.5  male   Third    7.7500
# 4   61.0  male   First   33.5000
# 5   62.0  male   First   26.5500
# 6   65.0  male   Third    7.7500
# 7   61.0  male   Third    6.2375
# 8   64.0  male   First  263.0000
# 9   65.0  male   First   26.5500
# 10  71.0  male   First   49.5042
# 11  64.0  male   First   26.0000
# 12  62.0  male   First   26.5500
# 13  62.0  male  Second   10.5000
# 14  61.0  male   First   32.3208
# 15  80.0  male   First   30.0000
# 16  70.0  male  Second   10.5000
# 17  70.0  male   First   71.0000
# 18  74.0  male   Third    7.7750

# %% [markdown]
# #SELECT WHERE NOT – Exclude specific values
# Get all passengers not in 1st class:

# %%
pd.read_sql("""
SELECT age, fare, sex, class
FROM titanic
WHERE fare > 100 OR age < 10
""", conn)
# Out:
#        age      fare     sex   class
# 0     2.00   21.0750    male   Third
# 1     4.00   16.7000  female   Third
# 2     2.00   29.1250    male   Third
# 3     8.00   21.0750  female   Third
# 4    19.00  263.0000    male   First
# ..     ...       ...     ...     ...
# 108   0.83   18.7500    male  Second
# 109   4.00   31.2750    male   Third
# 110   9.00   15.2458  female   Third
# 111  45.00  164.8667  female   First
# 112   4.00   11.1333    male   Third
#
# [113 rows x 4 columns]

# %% [markdown]
# #SELECT DISTINCT ... WHERE – Unique filtered values
# Get unique embark_town values for survivors only:

# %%
pd.read_sql("""
SELECT DISTINCT embark_town FROM titanic
WHERE survived = 1
""", conn)
# Out:
#    embark_town
# 0    Cherbourg
# 1  Southampton
# 2   Queenstown
# 3         None
